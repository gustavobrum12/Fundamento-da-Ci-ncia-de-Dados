# %%
# importando os pacotes

import pandas as pd # para importar csv
import matplotlib.pyplot as plt # para gráficos
import seaborn as sns # para gráficos
from sklearn.linear_model import LinearRegression # regressão linear
from sklearn.metrics import r2_score # R²

# %%
# importando os dados

dados = pd.read_csv("C:/Users/20221enpro0219/Downloads/score_updated.csv")
dados
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# ..    ...     ...
# 91    5.8      60
# 92    4.4      44
# 93    6.1      63
# 94    3.7      37
# 95    8.0      84
#
# [96 rows x 2 columns]

# %%
# (i) diagrama de dispersão

plt.scatter(dados['Hours'], dados['Scores'], color = 'lightcoral')
plt.title('Pontuação vs. Horas Estudadas')
plt.xlabel('Horas Estudadas')
plt.ylabel('Pontuação')
# Out:
# Text(0, 0.5, 'Pontuação')

# %%
# Separação de x e y

X = dados.iloc[:, :1] # variável independente
Y = dados.iloc[:, 1:] # variável dependente

# %%
# (ii) Ajuste do modelo (encontrar b0 e b1 )

modelo = LinearRegression()
modelo.fit(X, Y)
# Out:
# LinearRegression()

# %%
print('Coeficiente angular (beta_1): ', modelo.coef_)
print('Intercepto (beta_0): ', modelo.intercept_)
# Out:
# Coeficiente angular (beta_1):  [[9.90131826]]
# Intercepto (beta_0):  [1.86357663]

# %%
# fazendo predições para y usando x 

y_pred = modelo.predict(X)

# %%
# (i) diagrama de dispersão

plt.scatter(dados['Hours'], dados['Scores'], color = 'lightcoral')
plt.plot(X, y_pred, color = 'firebrick')
plt.title('Pontuação vs. Horas Estudadas')
plt.xlabel('Horas Estudadas')
plt.ylabel('Pontuação')
# Out:
# Text(0, 0.5, 'Pontuação')

# %%
# (iii) verificação  do coeficiente de determinação (R°)

r2_score (Y, y_pred)
# Out:
# 0.9813673346564977

# %%
# a pessoa com 4 anos de experiência ganha quanto

import numpy as np

X_novo = np.array([[4]])
modelo.predict(X_novo)
# Out:
# C:\tools\Anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[41.46884967]])
